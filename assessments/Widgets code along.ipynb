# %%
# Rendering functions
# Interactive displays need an imput and output
# Widget (sliders etc.)

# design a grid and place the in and output on the desired spots

# panel has themes, is nice.
# Endless possibilities ;)

# %%
import panel as pn
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

# %%
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# initializing panel
pn.extension()
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
def render_print(x):
    return x*x

# %%
interactive_panel = pn.interact(render_print, x=50, )

# %%
interactive_panel
# Out:
# Column
#     [0] Column
#         [0] IntSlider(end=150, name='x', start=-50, value=150)
#     [1] Row
#         [0] Str(int, name='interactive00112')

# %%
# Imput of the the interactive slider
interactive_panel[0]
# Out:
# Column
#     [0] IntSlider(end=150, name='x', start=-50, value=51)

# %%
# output of the slider
interactive_panel[1]
# Out:
# Row
#     [0] Str(int, name='interactive00112')

# %%
from bokeh.sampledata.iris import flowers
df = flowers
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
def render_plot(x='sepal_length', y='sepal_width'):
    p = figure()
    p.scatter(x=df[x], y=df[y])
    return p

# %%
columns = df.columns[:-1]
columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
inter_plot = pn.interact(render_plot, x=columns, y=columns)
inter_plot
# Out:
# Column
#     [0] Column
#         [0] Select(name='x', options=['sepal_length', ...], value='sepal_length')
#         [1] Select(name='y', options=['sepal_length', ...], value='sepal_width')
#     [1] Row
#         [0] Bokeh(Figure, name='interactive00463')

# %%
inter_plot[0]
# Out:
# Column
#     [0] Select(name='x', options=['sepal_length', ...], value='petal_length')
#     [1] Select(name='y', options=['sepal_length', ...], value='petal_length')

# %%
inter_plot[1]
# Out:
# Row
#     [0] Bokeh(Figure, name='interactive00356')

# %%
dashboard = pn.template.BootstrapTemplate(title = 'My first awesome dashboard', sidebar_width = 200)
dashboard.sidebar.append(inter_plot[0])
dashboard.main.append(inner_plot[1])

# %%
dashboard
# Out:
# BootstrapTemplate
#     [js_area] HTML(None, height=0, margin=0, sizing_mode='fixed', width=0)
#     [actions] TemplateActions()
#     [busy_indicator] LoadingSpinner(height=20, width=20)
#     [2225132178256] Column
#         [0] Select(name='x', options=['sepal_length', ...], value='petal_length')
#         [1] Select(name='y', options=['sepal_length', ...], value='petal_length')
#     [2225106494224] Row
#         [0] Str(None, name='interactive00214')
